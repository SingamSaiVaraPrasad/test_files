# %% [markdown]
# <a href="https://colab.research.google.com/github/SingamSaiVaraPrasad/test_files/blob/master/LinearRegressionPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/penguins.csv',usecols=['flipper_length_mm','body_mass_g'])
df.dropna(inplace=True)
df.reset_index(inplace=True,drop=True)
df
# Out:
#      flipper_length_mm  body_mass_g
# 0                181.0       3750.0
# 1                186.0       3800.0
# 2                195.0       3250.0
# 3                193.0       3450.0
# 4                190.0       3650.0
# ..                 ...          ...
# 337              207.0       4000.0
# 338              202.0       3400.0
# 339              193.0       3775.0
# 340              210.0       4100.0
# 341              198.0       3775.0
#
# [342 rows x 2 columns]

# %%
import seaborn as sns
# sns.scatterplot(x=df['flipper_length_mm'],y=df['body_mass_g'])
feature_name = "flipper_length_mm"
target_name = "body_mass_g"
figur=sns.scatterplot(data=df,x=feature_name,y=target_name)
figur.set_title("Plot of flipper length vs body mass")
# Out:
# Text(0.5, 1.0, 'Plot of flipper length vs body mass')

# %%
def linear_model_of_flipper(flip_lenght,wgt_of_flipLen,inteceptb):
  return flip_lenght*wgt_of_flipLen+inteceptb

wt_flip_len=45
intercept_flip_len=-5000
flip_lenghts=np.linspace(df.flipper_length_mm.min(),df.flipper_length_mm.max(),num=200)
body_masses=linear_model_of_flipper(flip_lenghts,wt_flip_len,intercept_flip_len)
fig1=sns.scatterplot(y=df['body_mass_g'],x=df['flipper_length_mm'])
fig1.plot(flip_lenghts,body_masses)

# %%
from sklearn.linear_model import LinearRegression

# Assuming df is your DataFrame
datalens = df['flipper_length_mm'].values
databody = df['body_mass_g'].values.reshape(-1, 1)
print(databody)
lr = LinearRegression()
lr.fit(datap, datb)
wt=lr.coef_
intercept=lr.intercept_
print(wt,intercept)

import numpy as np
final_lens=np.linspace(df.flipper_length_mm.min(),df.flipper_length_mm.max(),num=200)
final_masses=linear_model_of_flipper(final_lens,wt,intercept)
figg=sns.scatterplot(data=df,x='flipper_length_mm',y='body_mass_g')
figg.plot(final_lens,final_masses)
# Out:
# [181. 186. 195. 193. 190. 181. 195. 193. 190. 186. 180. 182. 191. 198.
#  185. 195. 197. 184. 194. 174. 180. 189. 185. 180. 187. 183. 187. 172.
#  180. 178. 178. 188. 184. 195. 196. 190. 180. 181. 184. 182. 195. 186.
#  196. 185. 190. 182. 179. 190. 191. 186. 188. 190. 200. 187. 191. 186.
#  193. 181. 194. 185. 195. 185. 192. 184. 192. 195. 188. 190. 198. 190.
#  190. 196. 197. 190. 195. 191. 184. 187. 195. 189. 196. 187. 193. 191.
#  194. 190. 189. 189. 190. 202. 205. 185. 186. 187. 208. 190. 196. 178.
#  192. 192. 203. 183. 190. 193. 184. 199. 190. 181. 197. 198. 191. 193.
#  197. 191. 196. 188. 199. 189. 189. 187. 198. 176. 202. 186. 199. 191.
#  195. 191. 210. 190. 197. 193. 199. 187. 190. 191. 200. 185. 193. 193.
#  187. 188. 190. 192. 185. 190. 184. 195. 193. 187. 201. 211. 230. 210.
#  218. 215. 210. 211. 219. 209. 215. 214. 216. 214. 213. 210. 217. 210.
#  221. 209. 222. 218. 215. 213. 215. 215. 215. 216. 215. 210. 220. 222.
# ...

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

penguins=pd.read_csv('/content/penguins.csv',usecols=['flipper_length_mm','body_mass_g'])
penguins.dropna(inplace=True)
penguins.reset_index(inplace=True,drop=True)
penguins

feature_name = 'flipper_length_mm'
target_name = 'body_mass_g'
data, target = penguins[[feature_name]], penguins[target_name]

lr=LinearRegression()
lr.fit(data,target)
wt=lr.coef_[0]
intcp=lr.intercept_
print(wt,' ',intcp)

def linear_model_op(length_values,body,intercepts):
  return length_values*wt+intercepts
fig=sns.scatterplot(data=penguins,x=feature_name,y=target_name)
lens=np.linspace(penguins[feature_name].min(),penguins[feature_name].max(),num=200)
masses=linear_model_op(lens,wt,intcp)
fig.plot(lens,masses,color='red')
# Out:
# 49.68556640610011   -5780.831358077066
